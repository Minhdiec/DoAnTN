# %% [markdown]
# ![image.png](attachment:b6374424-4579-44ec-9706-4fb1bb904b16.png)

# %% [markdown]
# ![image.png](attachment:33202fd9-73fb-4cdb-8299-2bf7da61fe8f.png)

# %% [markdown]
# quan sát 2 lỗi trên, đánh giá sao phải có 4 sao 5 sao, 1 sao, tại sao ở đây lại chỉ có 5 sao thôi? hiển thị rõ ràng

# %% [markdown]
# lỗi khi bấm thanh toán ![image.png](attachment:375a1b78-bb0f-43f5-bd93-b9372606b1fb.png)

# %% [markdown]
# lỗi css button
# ![image.png](attachment:93f789eb-6418-433d-8d7d-106eaa58923d.png)

# %% [markdown]
# 1. bỏ chữ thanh toán ằng số dư trong ví điện tử của bạn
# ![image.png](attachment:3b5a3706-40bc-4c56-aafa-45d265dedc97.png)
# bạn phải giả lập chọn momo thẻ, cod gì đó xong bấm vào phương thức popup đó ra màn hình thì thông báo đơn hàng thành công chứ k phải số dư của ví, ta đang giả lập chỉ cần chọn hình thức thanh toán rồi bấm thanh toán là đơn đã thanh toán thành công
# ![image.png](attachment:73d5ff8b-c664-4129-b8ad-3f6a0dbd91b6.png)

# %% [markdown]
# 2
# ở tài khoản admin bị lỗi ![image.png](attachment:3b6addcd-f2e8-482c-864b-7bd72b48649c.png)
# ![image.png](attachment:a70f0c26-7e5e-4fd0-929f-66fa9ea8e01f.png)
# admin tài khoản này chỉ xem như khách thôi, bạn thấy logic này đúng không? sửa sao cho tối ưu
# và ý của tôi là bên trang admin quản lí sẽ có thống kê dữ liệu sản phẩm tích cực tiêu cực thống kê chi tiết từng món, bạn hãy xây dựng nó vào trang admin quản trị => biểu đồ thống kê
# ![image.png](attachment:63a0283a-9644-41b6-8214-e23dbd1710ab.png) => csss lại phần lọc này
#  ![image.png](attachment:64548c70-6ed0-4562-918c-206504541917.png)
#  kiểm tra từng luồng lỗi trong tất cả code để fix code và bổ sung
#
# - với lại khi mà admin đăng nhập bằng tài khoản admin tự động nhảy sang trang quản trị admin và ở trang admin sẽ có click vào xem trang web

# %% [markdown]
# nút giỏ hàng ở đây không hoạt động => chạy lại tất cả chức năng để ko còn  những lỗi sót này nữa, chạy xong fix lỗi luôn hoặc thiếu cái j thì bổ sung
# ![image.png](attachment:e6b4ccc1-a0da-469b-af83-2fdfdb1a82b4.png)

# %% [markdown]
# 3. bỏ dòng này đi
# ![image.png](attachment:bee83e87-d907-4295-b02d-9c60ce185e4a.png)
#
# và mỗi bình luận đều gắn nhãn tích cực hay tiêu cực, hay trung lập ở cmt đó luôn
# ![image.png](attachment:5d8d858e-cd58-4c05-9a59-996f666bc31b.png)
# giả lập thanh toán đang lỗi, bấm vào ko thấy hiện chọn phương thức thanh toán momo, thẻ cod,.. rồi bấm vào pt cần thanh toán rồi sẽ đặt hàng thành công
#
# chỗ kính oval này
#  ![image.png](attachment:29af2d3b-3fdf-44f9-933f-56b1e667d59c.png)
#  bạn hãy vào link trang web này https://www.carfia.com/de/products/dublin-ca5506fc10 để làm detail sản phẩm cho
# kính oval, lưu ý chỉ lấy ảnh sản phẩm ở các góc độ khác nhau, không lấy ảnh người mẫu hay ảnh thông số, mô tả sảm phẩm bạn chỉnh lại
# bằng tiếng việt, bạn tự bịa ra cũng được

# %% [markdown]
# 4 loại bỏ những logic ko hợp lí ở trang admin ví dụ như này: tại sao lại có thêm vào đánh giá sản phẩm ở trang admin được? đó chỉ là khách hàng cmt thôi ko có quyền thêm, kiểm tra các chức năng crud khác cái nào ko đúng logic thì xóa đi,
# ![image.png](attachment:85c46710-3269-46cd-922e-bd41e0dfed4e.png)
#  tiêu đề : Chọn Đánh giá sản phẩm để thay đổi
# Thêm vào Đánh giá sản phẩm
# Thống kê cảm xúc (trên 50 đánh giá đang lọc/tìm): Tích cực 28 (56%) · Trung lập 8 (16%) · Tiêu cực 14 (28%) thừa thãi? bạn ghi
#
# Chọn Đánh giá sản phẩm để thay đổi là sai đấy, chỉ cần ghi thống kê bình luận: Tích cực 28 (56%) · Trung lập 8 (16%) · Tiêu cực 14 (28%)
# - chỗ chân trang footer viết sao cho hợp với đề tài trang web
# ![image.png](attachment:6305bd8f-77c7-4436-886f-a76d57b1ddf1.png)
# thay đổi câu nói banner: Mua sắm thông minh, nhận hàng nhanh chóng
# Hàng ngàn sản phẩm chính hãng, giá tốt mỗi ngày. Đổi trả dễ dàng trong 7 ngày, thanh toán linh hoạt nhiều hình thức.
# => thành ĐỊNH HÌNH ÁNH NHÌN, TÔN NÉT RIÊNG BẠN, Khám phá bộ sưu tập gọng kính mới nhất – Chuẩn gu, êm ái mỗi ngày
